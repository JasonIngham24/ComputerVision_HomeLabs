# %% [markdown]
# # Laplacian Operator and Tutorial.
# Following:
# 1. https://docs.opencv.org/3.4/d5/db5/tutorial_laplace_operator.html
# 2. https://pyimagesearch.com/2021/04/28/opencv-smoothing-and-blurring/
# 3. https://docs.opencv.org/3.4/d2/d2c/tutorial_sobel_derivatives.html
# 4. https://docs.opencv.org/4.x/d4/d13/tutorial_py_filtering.html
#
# Acknowlegement: Image by Tomascastelazo, CC BY-SA 3.0 <https://creativecommons.org/licenses/by-sa/3.0>, via Wikimedia Commons

# %%
# %pip install matplotlib
# %pip install opencv-python
# %pip install numpy
# Out:
# Requirement already satisfied: matplotlib in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from opencv-python) (2.4.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (2.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
## Function to display image using Matplotlib
def display_image(image1, strng):
    image = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB) ##BGR to RGB conversion for display using Matplotlib
    plt.title(strng)
    plt.imshow(image)
    plt.show()

# %% [markdown]
# ## Read Image

# %%
img = cv2.imread("cat1.jpg")
display_image(img, "Original Image")

# %% [markdown]
# ## Blurring Image

# %%
img2 = cv2.GaussianBlur(img, (3, 3), 30)
display_image(img2, "Gaussian Blur")

# %%
src_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display_image(src_gray, "Grayscale ")

# %% [markdown]
# ## Subtracting Original Image from Blurred Versions

# %%
src_original = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
img3 = src_original - src_gray
display_image(img3, "Subtraction")

# %% [markdown]
# ## Using Median Blur

# %%
src_original = cv2.medianBlur(img, 5)
display_image(src_original, "Median Blur")

# %% [markdown]
# ## Sobel Filter

# %%
scale = 1
delta = 0
ddepth = cv2.CV_16S  ## To prevent overflow
kernel_size = 3

grad_x = cv2.Sobel(src_gray, ddepth, 1, 0, ksize=kernel_size, scale=scale, delta=delta, borderType=cv2.BORDER_DEFAULT)
grad_y = cv2.Sobel(src_gray, ddepth, 0, 1, ksize=kernel_size, scale=scale, delta=delta, borderType=cv2.BORDER_DEFAULT)

abs_grad_x = cv2.convertScaleAbs(grad_x)
abs_grad_y = cv2.convertScaleAbs(grad_y)

grad = cv2.addWeighted(abs_grad_x, 0.5, abs_grad_y, 0.5, 0) ## approximating gradient
display_image(grad, "Sobel")

# %% [markdown]
# ## Laplacian Operator

# %%
dst = cv2.Laplacian(img, ddepth, ksize=kernel_size)
abs_dst = cv2.convertScaleAbs(dst)
display_image(abs_dst, "Laplacian Operator W/O Bluring")

dst = cv2.Laplacian(src_original, ddepth, ksize=kernel_size)
abs_dst = cv2.convertScaleAbs(dst)
display_image(abs_dst, "Laplacian Operator with the Median Blur")
