# %% [markdown]
# #  Image Thresholding, Canny Edge Detection and Image Stitching.
# Following:
# 1. https://docs.opencv.org/4.x/d8/d19/tutorial_stitcher.html
# 2. https://github.com/opencv/opencv_extra/blob/4.x/testdata/stitching/boat3.jpg

# %%
# %pip install matplotlib
# %pip install opencv-python
# %pip install numpy
# Out:
# Requirement already satisfied: matplotlib in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: opencv-python in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (from opencv-python) (2.4.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\Users\jason\anaconda3\envs\SURE312\Lib\site-packages (2.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os
import cv2
import numpy as np
import utilities 
import matplotlib.pyplot as plt

# %% [markdown]
# ### Read Image

# %%
img_noise = cv2.imread("Coins.png")
utilities.display_image(img_noise, "Noisy")
img_noise.shape
# Out:
# (325, 474, 3)

# %% [markdown]
# ### Apply filters to remove Noise

# %%
img_noise.shape
noisy_gray = cv2.cvtColor(img_noise, cv2.COLOR_BGR2GRAY)
noisy_gray.shape
img_non = cv2.medianBlur(noisy_gray, 5)
#img_non = cv2.GaussianBlur(img_noise, (13, 13), sigmaX=0)
utilities.display_image(img_non, "Non Noisy")

# %% [markdown]
# ### Thresholding Image Using Otsu's method

# %%
otsu_threshold, image_result = cv2.threshold(
    img_non, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU,
)

utilities.display_image(image_result, "thresholded")
otsu_threshold
# Out:
# 173.0

# %% [markdown]
# ### Inverting Image

# %%
invert = cv2.bitwise_not(image_result)
utilities.display_image(invert, "thresholded and inverted")

# %% [markdown]
# ### Getting objects

# %%
img1_bg = cv2.bitwise_and(img_non,img_non,mask = invert)
utilities.display_image(img1_bg, "segmented objects")

# %% [markdown]
# ### Getting edges (using Sobel Operator)

# %%
scale = 1
delta = 0
ddepth = cv2.CV_16S  ## To prevent overflow
kernel_size = 3

grad_x = cv2.Sobel(invert, ddepth, 1, 0, ksize=kernel_size, scale=scale, delta=delta, borderType=cv2.BORDER_DEFAULT)
grad_y = cv2.Sobel(invert, ddepth, 0, 1, ksize=kernel_size, scale=scale, delta=delta, borderType=cv2.BORDER_DEFAULT)

abs_grad_x = cv2.convertScaleAbs(grad_x)
abs_grad_y = cv2.convertScaleAbs(grad_y)

grad = cv2.addWeighted(abs_grad_x, 0.5, abs_grad_y, 0.5, 0) ## approximating gradient
utilities.display_image(grad, "Edges with Sobel")

# %% [markdown]
# ### Using Laplacian

# %%
ddepth = cv2.CV_16S  ## To prevent overflow
kernel_size = 3

dst = cv2.Laplacian(invert, ddepth, ksize=kernel_size)
abs_dst = cv2.convertScaleAbs(dst)
utilities.display_image(abs_dst, "Edges with Laplacian Operator")

# %% [markdown]
# ## Image Stitching

# %%
## getting images
imgs = []
for i in range(1,8):
    image_path = "office_2/"
    img_name = "officepic" + str(i) + ".jpg"
    imgpath = os.path.join(image_path, img_name)
    img= cv2.imread(imgpath)
    utilities.display_image(img, str(i))
    imgs.append(img)

# %%
# sticther object  
stitcher = cv2.Stitcher.create()
status, panorama = stitcher.stitch(imgs)

if status != cv2.Stitcher_OK:
    print("Can't stitch images, error code = %d" % status)

cv2.imwrite("panorama_boat.jpg", panorama)
print("stitching completed successfully.")

utilities.display_image(panorama, "Panorama")

# %%
## getting images
imgs = []
for i in range(1,4):
    img_name = "boat" + str(i) + ".jpg"
    img= cv2.imread(img_name)
    utilities.display_image(img, str(i))
    #imgs.append(img)

# sticther object  
stitcher = cv2.Stitcher.create()
status, panorama = stitcher.stitch(imgs)

if status != cv2.Stitcher_OK:
    print("Can't stitch images, error code = %d" % status)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[16], line 6
#       4     img_name = "boat" + str(i) + ".jpg"
#       5     img= cv2.imread(img_name)
# ----> 6     utilities.display_image(img, str(i))
#       7     #imgs.append(img)
#       8
#       9 # sticther object
#      10 stitcher = cv2.Stitcher.create()
#
# File c:\Users\jason\OneDrive\Desktop\New Paltz\Spring 2026\Computer Vision\Practical 4\utilities.py:10, in display_image(image1, strng)
#       9 def display_image(image1, strng):
# ---> 10     image = cv2.cvtColor(image1, cv2.COLOR_BGR2RGB) ##BGR to RGB conversion for display using Matplotlib
#      11     plt.title(strng)
#      12     plt.imshow(image)
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
